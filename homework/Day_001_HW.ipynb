# %%
import numpy as np
import matplotlib.pyplot as plt

w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)
y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title('Assume we have data points')
plt.legend(loc = 2);
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title('Assume we have data(And prediction)')
plt.legend(loc = 2)
plt.show()

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預設值
    Return:
        - mae: MAE
    """
    mae = sum(abs(y - yp)) / len(y)
    return mae

MAE = mean_absolute_error(y, y_hat)
print("The MAE is %.3f" % (MAE))
# Out:
# The MAE is 11.191

# %%
import math

def mean_squared_error(y, yp):
    """
    計算 MSE
    Arg:
        - y: 實際值
        - yp: 預設值
    Return:
        - mse: MSE
    """
    
    # MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2}
    mse = sum(np.power(y - yp, 2)) / len(y)
    return mse
    
MSE = mean_squared_error(y, y_hat)
print("MSE is %.3f" % (MSE))
# Out:
# MSE is 197.331

# %%
"""
作業2
請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
1. 你選的這組資料為何重要
2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
3. 蒐集而來的資料型態為何
4. 這組資料想解決的問題如何評估

Competitions: The 3rd YouTube-8M Video Understanding Challenge
A1.自動地替辨識出影片內容。縮小尋找影片特定內容的時間，尋找/加強影片的價值。
A2.網路上的免費影片，或是個人手機上自己拍攝的短片/影片
A3.資料型態為影片(圖形/影像)
A4.以人類活動為辨識目標。首先辨識出影片每禎內的人，進而辨識出年紀/性別等等特徵，再來辨識姿勢；
   或是辨識出畫面中的物品，與畫面出人的姿勢做關聯性的判斷。

"""
# Out:
# '\n作業2\n\n'

# %%
"""
作業3
想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
3. 蒐集而來的資料型態為何
4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)

A1. 計算單位時間內，所獲得的金錢。數值高，則表示業績較高。
A2. 會希望車隊同事能回報至少以下營業資料，a.單次開始/結束時間 b.本次金額 c.本次開始/結束地點 d.心情愉快評分 e.當日總營業時數。
A3. 皆為數字。會由各種管道獲得資料，進而輸入進電腦/資料庫。
A4. 計算方式：單次金額*愉快評分=單次心靈物質得分，sum(單次心靈物質得分)/當日總營業時數=單位時間內所賺取的心靈物質得分。
    驗證方式：邀請部分不在這時段載客的同事，調整到得分較高的時段上班，再回顧當月的心靈物質得分。
"""
